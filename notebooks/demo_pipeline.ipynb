# %% [markdown]
# # Demo: Multi-Agent Pipeline
# This notebook demonstrates the stub pipeline.

# %%
from src.core.pipeline import Pipeline
pipeline = Pipeline()
result = pipeline.run("What is the capital of France?")
print(result)

# %%
# Run pipeline with config-driven MVP planner and retriever
from src.core.pipeline import Pipeline
pipeline = Pipeline()
result = pipeline.run("What is the capital of France? Explain why.")
print(result)
